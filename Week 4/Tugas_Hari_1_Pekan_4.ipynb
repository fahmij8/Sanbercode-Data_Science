# %% [markdown]
# # Tugas Hari 1 - Pekan 4 (Python - Data Science)
# ### Organized by Sanbercode
# ##### Nama : Fahmi Jabbar (fahmijabbar12@gmail.com)

# %% [markdown]
# <h1>Soal 1: Pemahaman Machine Learning</h1>
#
# Jawab/Kerjakan pertanyaan/perintah di bawah ini dengan bahasa kalian sendiri:
#
# - Apa itu machine learning?
# - Apa itu data feature dan data target?
# - Apa Perbedaan Supervised Learning dan Unsupervised Learning?
# - Apa Jenis2 yang ada di dalam Supervised Learning? Jelaskan Perbedaannya!
# - Apa perbedaan Hyperparameter dan Parameter?
# - Sebutkan Langkah-langkah dalam mengaplikasikan algoritma apapun dalam machine learning!

# %% [markdown]
# **Jawaban:**
#
# 1. Machine learning adalah suatu algoritma yang digunakan untuk membuat komputer menjadi terlatih untuk memutuskan sesuatu berdasarkan inputan yang diberikannya dan teknik pengaplikasiannya (Fahmi Jabbar, 2020)
#
# 2. Data feature adalah variable yang digunakan pada algoritma ML (data), sedangkan data target adalah Hasil dari komputasi algoritma ML. (Hasil prediksi)
#
# 3. Supervised learning kita melabeli hasil prediksi, Unsupervised learning hasil prediksi dilabeli oleh hasil algoritma MLnya sendiri (cluster)
#
# 4. Supervised learning terdiri dari regresion (memprediksi data selanjutnya/sebelumnya menggunakan data yang ada), clasification (mengklasifikasikan suatu data), dan masih banyak yang lainnya
#
# 5. Hyperparameter adalah suatu data yang dapat kita ubah ubah nilainya (tuning) sedangkan parameter adalah sebaliknya tidak dapat di tuning
#
# 6. Diantaranya :
# - menentukan tujuan
# - mengumpulkan data
# - pre-processing data + buat hypotesis
# - pelatihan data/uji hypotesis
# - analisa hasil hipotesis dan hasil pelatihan
# - Mengambil kesimpulan (tujuan tercapai/tidak)

# %% [markdown]
# ---

# %% [markdown]
# <h1>Soal 2: Pemahaman Machine Learning</h1>
#
# Pelajarilah secara garis besar suatu model/algoritma machine learning, kemudian aplikasikan untuk membuat model bagi data (variable x, y) di bawah ini. Kemudian buatlah prediksi terhadap data training dan data baru di interval 20-30.
#
# - Plot data asli, data hasil prediksi terhadap data training, data hasil prediksi terhadap data baru
# - Tunjukan beberapa parameter yang dimiliki model yang telah kalian buat

# %%
import matplotlib.pyplot as plt
import numpy as np

rng = np.random.RandomState(42)
x = 20 * rng.rand(50)
y = x**2 + 2 * x + - 1 + rng.randn(50)

# data yang akan di prediksi
x_new = np.arange(20, 30, 0.5)

fig, ax = plt.subplots(figsize=(12, 6))
ax.scatter(x, y)
ax.set_xlabel('X-Value')
ax.set_ylabel('Y-Value')
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor
tree = DecisionTreeRegressor(max_depth=4, min_samples_split=6, min_samples_leaf=6)
x_train = x[:, np.newaxis]
tree.fit(x_train, y)
x_pred = x_new[:, np.newaxis]
y_pred = tree.predict(x_pred)
y_train = tree.predict(x_train)

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.scatter(x, y, label='Data Asli', color='b')
ax.scatter(x, y_train, label='Prediksi terhadap data training', color='y')
ax.plot(x_pred, y_pred, label='Prediksi terhadap data baru', color='g')
ax.set_xlabel('X-Value')
ax.set_ylabel('Y-Value')
plt.legend(bbox_to_anchor=(1.1,1.2))
plt.show()

# %% [markdown]
# Contoh jawaban hasil pembuatan model dengan algoritma DecisionTreeRegressor (jawaban tidak harus sama):
#
# ![alt text](https://drive.google.com/uc?id=1R0mGnMp3DqEsHDiH2_IL4XSS2Roew0wo)

# %%
from sklearn.tree import export_graphviz
export_graphviz(
    tree,
    out_file = "dt.dot",
    filled =True
)

# %%
import pydot
from IPython.display import Image
(graph,) = pydot.graph_from_dot_file('/content/dt.dot')
graph.write_png('/content/dt.png')
Image('/content/dt.png')

# %% [markdown]
# Contoh jawaban parameters (tidak harus sama):
#
# - Feature Importance : array([1.])
# - n features : 1
#
# Tree Graph :
#
# ![alt text](https://drive.google.com/uc?id=1GM0ba_qjm_e5oLhE9v6pVt2uRBBW6FH9)
